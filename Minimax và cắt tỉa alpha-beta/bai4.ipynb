# %%
import math

# %%
def create_board(n):
    return [[None for _ in range(n)] for _ in range(n)]

# %%
board10 = create_board(10)
print("Bai 4 - Tao board 10x10 thanh cong")
# Out:
# Bai 4 - Tao board 10x10 thanh cong
