# %%
import math

EMPTY = None

# %%
def create_board(n):
    return [[EMPTY for _ in range(n)] for _ in range(n)]

# %%
board5 = create_board(5)
print("Bai 3 - Tao board 5x5 thanh cong")
# Out:
# Bai 3 - Tao board 5x5 thanh cong
